# %% [markdown]
# # Characteristics Curve of LED

# %%
#importing libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#assigning values
h = 6.26e-34
c = 3e8
lam = 870e-9
tr = 60e-9
tnr = 100e-9
q = 1.6e-19

# %%
#calculation
t = (tr*tnr)/(tr+tnr)
print('Time: '+str(t)+' seconds')

nint = t/tr
print('NINT:',nint)

I = np.arange(0, 40, 1)*1e-3
pint = [0]*I

for i in range(40):
    pint[i] = (nint*I[i]*h*c)/(q*lam)
# Out:
# Time: 3.749999999999999e-08 seconds
# NINT: 0.6249999999999999

# %%
#plotting
plt.figure()
plt.plot(I, pint)
plt.title('Characteristics Curve of LED')
plt.xlabel('Current(A)----------->')
plt.ylabel('Internally Generated Optical Power(W)----------->')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Internally Generated Optical Power(W)----------->')
